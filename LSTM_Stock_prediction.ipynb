# %% [markdown]
# # Stock value prediction from Open, High, Low

# %% [markdown]
# # Import module

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt2
import pandas as pd
from pandas import datetime
from pandas import DataFrame
from pandas import concat
import math, time
import itertools
from sklearn import preprocessing
import datetime
from sklearn.metrics import mean_squared_error
from math import sqrt
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.recurrent import LSTM
from keras.models import load_model
import keras
import pandas_datareader.data as web
import h5py
import os
import keras.backend as K
from keras.utils.generic_utils import get_custom_objects

from collections import deque
from io import StringIO
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Input parameters

# %%
stock_name = '^GSPC'
seq_len = 22
d = 0.2
shape = [4, seq_len, 1] # feature, window, output
neurons = [128, 128, 32, 1]
epochs = 200

neurons_layer = 1
optimizer = 'Adam'
loss = 'mse'

# 從這邊寫入參數決定是Train 或是 Predict

# action = 'predict'
action = 'train'

# loss = 'risk_estimation'

# %% [markdown]
# # 1. Download data and normalize it
# Data since date 'start' to today

# %%
def normalize_df(df):
    yesterday_value = pd.concat([df[:1], df[:len(df)-1]], ignore_index=True)
    df = pd.concat([df[:]], ignore_index=True)
    df = df / yesterday_value
    return df

def denormalize(origin_value, normalized_p):
    yesterday_value = np.concatenate((origin_value[:1], origin_value[:len(origin_value)-1]))
    normalized_value = normalized_p * yesterday_value
    return normalized_value

# %%
import dateutil.parser

def get_data_last_updated_date(stock_name):
    data_path = 'data/' + stock_name
    if os.path.exists(data_path):
        with open(data_path, 'r') as f:
            last_day_string = deque(f, 1).pop().split(",")[0]
            start = datetime.datetime.strptime(last_day_string, '%Y-%m-%d') + datetime.timedelta(days=1)
            start = start.date()
            return start
    else:
        return datetime.datetime(2013, 1, 1).date()

def update_stock_data(stock_name):
    start = get_data_last_updated_date(stock_name)
    end = datetime.date.today()
    data_path = 'data/' + stock_name
    
    if os.path.exists(data_path):
        with open(data_path, 'r') as f:
            last_day_string = deque(f, 1).pop().split(",")[0]
            start = datetime.datetime.strptime(last_day_string, '%Y-%m-%d')
            start = start.date()

    if start > datetime.date.today():
        print ('stock data already latest')
        return
    else:
        try:
            df = web.DataReader(stock_name, "yahoo", start)
        except:
            print('retrying data from yahoo...')
            update_stock_data(stock_name)
            return
        
        if os.path.exists(data_path):
            with open(data_path, 'a') as f:
#                 print('df = ',df, 'start = ', start)
                mask = df.index > str(start)
                df = df[mask]
                df.to_csv(f, header=False)
                print ('stock data appended')
        else:
            if not os.path.exists('data'):
                os.mkdir('data')
            df.to_csv(data_path)
            print ('stock data create')
        
                
def get_stock_data(stock_name, drop_unuse_column=True):
    data_path = 'data/' + stock_name
    df = pd.read_csv(os.path.join(data_path))
    if drop_unuse_column:
        df.drop(['Volume', 'Close', 'Date'], 1, inplace=True)
    return df

# %%
update_stock_data(stock_name)
origin_df = get_stock_data(stock_name)
df = normalize_df(origin_df)
# Out:
# stock data appended

# %% [markdown]
# # 2. Plot out the Normalized Adjusted close price

# %%
def plot_stock(df):
    print(df.head())
    plt.plot(df['Adj Close'], color='red', label='Adj Close')
    plt.legend(loc='best')
    plt.show()

# %%
plot_stock(origin_df)
plot_stock(df)
plot_stock(denormalize(origin_df,df))
# Out:
#           Open         High          Low    Adj Close
# 0  1402.430054  1426.739990  1398.109985  1426.189941
# 1  1426.189941  1462.430054  1426.189941  1462.420044
# 2  1462.420044  1465.469971  1455.530029  1459.369995
# 3  1459.369995  1467.939941  1458.989990  1466.469971
# 4  1466.469971  1466.469971  1456.619995  1461.890015
#        Open      High       Low  Adj Close
# 0  1.000000  1.000000  1.000000   1.000000
# 1  1.016942  1.025015  1.020084   1.025403
# 2  1.025403  1.002079  1.020572   0.997914
# 3  0.997914  1.001685  1.002377   1.004865
# 4  1.004865  0.998999  0.998376   0.996877
#           Open         High          Low    Adj Close
# 0  1402.430054  1426.739990  1398.109985  1426.189941
# 1  1426.189941  1462.430054  1426.189941  1462.420044
# 2  1462.420044  1465.469971  1455.530029  1459.369995
# 3  1459.369995  1467.939941  1458.989990  1466.469971
# 4  1466.469971  1466.469971  1456.619995  1461.890015

# %% [markdown]
# # 3. Slice data for training

# %%
def get_lstm_data(df, seq_len):
    amount_of_features = len(df.columns)
    data = df.as_matrix() 
    sequence_length = seq_len # index starting from 0
    result = []
    
    for index in range(len(data) - sequence_length + 1): # maxmimum date = lastest date - sequence length + 1
        result.append(data[index: index + sequence_length]) # index : index + 22days
        
    result = np.array(result)
    return result

def load_data(df, seq_len):
    amount_of_features = len(df.columns)
    result = get_lstm_data(df, seq_len)
    row = round(0.9 * result.shape[0]) # 90% split
    
    X_train = result[:int(row), :] # 90% date
    y_train = result[1:int(row) + 1, :, -1][:,-1] # day m + 1 adjusted close price
    
    X_test = result[int(row): -1 , :]
    y_test = result[int(row) + 1: , -1][:,-1] 
    
    X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], amount_of_features))
    X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], amount_of_features))
    
    return [X_train, y_train, X_test, y_test]

# %%
X_train, y_train, X_test, y_test = load_data(df, seq_len)
origin_X_Train, origin_y_Train, origin_X_test, origin_y_test = load_data(origin_df, seq_len)

print(X_train.shape[0], X_train.shape[1], X_train.shape[2])
print(y_train.shape[0])
# Out:
# 1135 22 4
# 1135

# %% [markdown]
# # 4. Buidling neural network

# %%
def build_model2(layers, neurons, d):
    model = Sequential()
    
    for i in range(neurons_layer):
        model.add(LSTM(neurons[0], input_shape=(layers[1], layers[0]), return_sequences=True))
        model.add(Dropout(d))

    model.add(LSTM(neurons[1], input_shape=(layers[1], layers[0]), return_sequences=False))
    model.add(Dropout(d))
        
    model.add(Dense(neurons[2],kernel_initializer="uniform",activation='relu'))        
    model.add(Dense(neurons[3],kernel_initializer="uniform",activation='linear'))
    model.compile(loss=loss, optimizer=optimizer, metrics=['accuracy'])
    model.summary()
    return model

# %% [markdown]
# # 5. Plot function

# %%
def plot_value(stock_name, predict, actual, dir_name, file_name):
    if not os.path.isdir(dir_name):
        os.makedirs(dir_name)
    
    fig_path = dir_name + '/' + file_name
    
    plt2.plot(predict, color='red', label='Prediction')
    plt2.plot(actual,color='blue', label='Actual')
    plt2.legend(loc='best')
    plt2.title('The test result for {}'.format(stock_name))
    plt2.xlabel('Days')
    plt2.ylabel('Adjusted Close')
    plt2.savefig(fig_path, format='png', bbox_inches='tight', transparent=True)
    plt2.close('all')

# %%
# 損益計算、價錢預測
def plot_result(stock_name, pred, test, epochs, date):
    volumn_change_p = []
    volumn_change_y_test = []
    profit_p = []
    profit_y_test = []
    total_profit_p = []
    total_profit_y_test = []
    for i in range(len(pred)):
        if i == 0:
            volumn_change_p.append(0)
            volumn_change_y_test.append(0)
            
            profit_p.append(0)
            profit_y_test.append(0)
            
            total_profit_p.append(0)
            total_profit_y_test.append(0)
        else:
            volumn_change_p.append(pred[i] - pred[i-1])
            volumn_change_y_test.append(test[i] - test[i-1])

            if pred[i] > pred[i-1]:
                profit_p.append(test[i] - test[i - 1])
            else:
                profit_p.append(test[i - 1] - test[i])
            
            test_earn = abs(volumn_change_y_test[i] - volumn_change_y_test[i - 1])
            profit_y_test.append(test_earn)
            
            total_profit_p.append(total_profit_p[i - 1] + profit_p[i])
            total_profit_y_test.append(total_profit_y_test[i - 1] + profit_y_test[i])
            
    figname = stock_name + '_epochs' + str(epochs) + '.png'
    
    dir_prefix = str(neurons_layer) + 'layer_' + optimizer + stock_name
    
    
    subdir = '/' +  date.strftime("%Y%m%d%H%M%S") + '/' + 'price' 
    dir_name = dir_prefix + subdir
    plot_value(stock_name, pred, test, dir_name, figname)
    
    subdir = '/' +  date.strftime("%Y%m%d%H%M%S") + '/' + 'value_change'     
    dir_name = dir_prefix + subdir
    plot_value(stock_name, volumn_change_p, volumn_change_y_test, dir_name, figname)
    
    subdir = '/' +  date.strftime("%Y%m%d%H%M%S") + '/' + 'profit' 
    dir_name = dir_prefix + subdir
    plot_value(stock_name, profit_p, profit_y_test, dir_name, figname)
    
    subdir = '/' +  date.strftime("%Y%m%d%H%M%S") + '/' + 'profit_sum' 
    dir_name = dir_prefix + subdir
    plot_value(stock_name, total_profit_p, total_profit_y_test, dir_name, figname)

# %% [markdown]
# # 6. Start train or predict

# %%
def get_last_predict_data_date(stock_name):
    last_date_predicted = get_predicted_data(stock_name)['Date'].tail(1).values[0]
    return last_date_predicted

def save_predicted_data(stock_name, df):
    dir_path = 'data/predicted/'
    data_path = dir_path + stock_name + '.csv'
    if os.path.exists(data_path):
        with open(data_path, 'a') as f:
            df = df[df.index > get_last_predict_data_date(stock_name)]
            df.to_csv(f, header=False)
            print ('predicted data appended')
    else:
        if not os.path.exists(dir_path):
            os.mkdir(dir_path)
        df.to_csv(data_path)
        print ('predicted data create')
    return

def get_predicted_data(stock_name):
    data_path = 'data/predicted/' + stock_name + '.csv'
    df = None
    if os.path.exists(data_path):
        df = pd.read_csv(os.path.join(data_path))
            
    return df
    
def get_unpredict_data(stock_name):
    stock_df = get_stock_data(stock_name,drop_unuse_column=False)
    predicted_data = get_predicted_data(stock_name)
    if predicted_data is not None:
        data_to_pred_length = len(stock_df[stock_df['Date'] > get_last_predict_data_date(stock_name)])
        stock_df = stock_df.tail(data_to_pred_length + seq_len - 1)
    
    data_to_lstm = stock_df.copy()
    data_to_lstm.drop(['Volume', 'Close', 'Date'], 1, inplace=True)
    lstm_data = get_lstm_data(data_to_lstm, seq_len)
    return [lstm_data, stock_df[seq_len-1:]]

# %%
run_date = datetime.datetime.now()
if action == 'train':    
    model = build_model2(shape, neurons, d)
    save_plot_epochs = 25
    for i in range(int(epochs / save_plot_epochs)):
        model.fit(
            X_train,
            y_train,
            batch_size=512,
            epochs=save_plot_epochs,
            validation_split=0.1,
            verbose=1)
        predict_y = model.predict(X_test).reshape(-1)
        
        denormalized_test = denormalize(origin_y_test, y_test)
        denormalized_pred = denormalize(origin_y_test, predict_y)
    
        plot_result(stock_name, denormalized_pred, denormalized_test, save_plot_epochs * (i + 1), run_date)
    model.save('LSTM_Stock_prediction.h5')
elif action == 'predict':
    model = load_model('LSTM_Stock_prediction.h5')
    x_to_predict, df_to_predict = get_unpredict_data(stock_name)
    
    if len(x_to_predict) < 1:
        print ('all price is already predicted , thread stop')
    else:
        predict_y_normalized = model.predict(x_to_predict).reshape(-1)        
        result = pd.DataFrame(index=df_to_predict.Date)
#         result['tomorrow_rate_predicted'] = predict_y_normalized
        result['today_close'] = df_to_predict['Close'].values
        result['tomorrow_price_predicted'] = predict_y_normalized * result['today_close']
        result['create_date'] = str(run_date.date())
        save_predicted_data(stock_name, result)
        print('new price predition append , file saved')
else:
    print('use train or predict')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 22, 128)           68096
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 22, 128)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                4128
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 203,841
# Trainable params: 203,841
# Non-trainable params: 0
# _________________________________________________________________
# Train on 1021 samples, validate on 114 samples
# Epoch 1/25
# 1021/1021 [==============================] - 1s 1ms/step - loss: 0.9925 - acc: 0.0000e+00 - val_loss: 0.9623 - val_acc: 0.0000e+00
# Epoch 2/25
# 1021/1021 [==============================] - 1s 760us/step - loss: 0.9452 - acc: 0.0000e+00 - val_loss: 0.8816 - val_acc: 0.0000e+00
# Epoch 3/25
# 1021/1021 [==============================] - 1s 783us/step - loss: 0.8486 - acc: 0.0000e+00 - val_loss: 0.7303 - val_acc: 0.0000e+00
# Epoch 4/25
# 1021/1021 [==============================] - 1s 778us/step - loss: 0.6820 - acc: 0.0000e+00 - val_loss: 0.5265 - val_acc: 0.0000e+00
# Epoch 5/25
# 1021/1021 [==============================] - 1s 796us/step - loss: 0.4766 - acc: 0.0000e+00 - val_loss: 0.3241 - val_acc: 0.0000e+00
# Epoch 6/25
# 1021/1021 [==============================] - 1s 763us/step - loss: 0.2789 - acc: 9.7943e-04 - val_loss: 0.1432 - val_acc: 0.0000e+00
# Epoch 7/25
# 1021/1021 [==============================] - 1s 742us/step - loss: 0.1079 - acc: 9.7943e-04 - val_loss: 0.0183 - val_acc: 0.0000e+00
# Epoch 8/25
# 1021/1021 [==============================] - 1s 756us/step - loss: 0.0116 - acc: 9.7943e-04 - val_loss: 0.0162 - val_acc: 0.0000e+00
# Epoch 9/25
# 1021/1021 [==============================] - 1s 765us/step - loss: 0.0348 - acc: 9.7943e-04 - val_loss: 0.0788 - val_acc: 0.0000e+00
# Epoch 10/25
# 1021/1021 [==============================] - 1s 721us/step - loss: 0.0859 - acc: 9.7943e-04 - val_loss: 0.0839 - val_acc: 0.0000e+00
# Epoch 11/25
# 1021/1021 [==============================] - 1s 727us/step - loss: 0.0785 - acc: 9.7943e-04 - val_loss: 0.0450 - val_acc: 0.0000e+00
# Epoch 12/25
# 1021/1021 [==============================] - 1s 730us/step - loss: 0.0371 - acc: 9.7943e-04 - val_loss: 0.0108 - val_acc: 0.0000e+00
# Epoch 13/25
# 1021/1021 [==============================] - 1s 759us/step - loss: 0.0093 - acc: 9.7943e-04 - val_loss: 1.9815e-05 - val_acc: 0.0000e+00
# Epoch 14/25
# 1021/1021 [==============================] - 1s 766us/step - loss: 0.0033 - acc: 9.7943e-04 - val_loss: 0.0061 - val_acc: 0.0000e+00
# Epoch 15/25
# 1021/1021 [==============================] - 1s 805us/step - loss: 0.0116 - acc: 9.7943e-04 - val_loss: 0.0156 - val_acc: 0.0000e+00
# Epoch 16/25
# 1021/1021 [==============================] - 1s 774us/step - loss: 0.0194 - acc: 9.7943e-04 - val_loss: 0.0200 - val_acc: 0.0000e+00
# Epoch 17/25
# 1021/1021 [==============================] - 1s 787us/step - loss: 0.0216 - acc: 9.7943e-04 - val_loss: 0.0175 - val_acc: 0.0000e+00
# Epoch 18/25
# 1021/1021 [==============================] - 1s 780us/step - loss: 0.0187 - acc: 9.7943e-04 - val_loss: 0.0107 - val_acc: 0.0000e+00
# Epoch 19/25
# 1021/1021 [==============================] - 1s 727us/step - loss: 0.0113 - acc: 9.7943e-04 - val_loss: 0.0039 - val_acc: 0.0000e+00
# Epoch 20/25
# 1021/1021 [==============================] - 1s 710us/step - loss: 0.0051 - acc: 9.7943e-04 - val_loss: 3.0348e-04 - val_acc: 0.0000e+00
# Epoch 21/25
# 1021/1021 [==============================] - 1s 733us/step - loss: 0.0029 - acc: 9.7943e-04 - val_loss: 6.3894e-04 - val_acc: 0.0000e+00
# Epoch 22/25
# 1021/1021 [==============================] - 1s 720us/step - loss: 0.0041 - acc: 9.7943e-04 - val_loss: 0.0030 - val_acc: 0.0000e+00
# Epoch 23/25
# 1021/1021 [==============================] - 1s 768us/step - loss: 0.0065 - acc: 9.7943e-04 - val_loss: 0.0044 - val_acc: 0.0000e+00
# Epoch 24/25
# 1021/1021 [==============================] - 1s 764us/step - loss: 0.0070 - acc: 9.7943e-04 - val_loss: 0.0038 - val_acc: 0.0000e+00
# Epoch 25/25
# 1021/1021 [==============================] - 1s 730us/step - loss: 0.0061 - acc: 9.7943e-04 - val_loss: 0.0019 - val_acc: 0.0000e+00
# Train on 1021 samples, validate on 114 samples
# Epoch 1/25
# 1021/1021 [==============================] - 1s 752us/step - loss: 0.0042 - acc: 9.7943e-04 - val_loss: 3.7114e-04 - val_acc: 0.0000e+00
# Epoch 2/25
# 1021/1021 [==============================] - 1s 734us/step - loss: 0.0031 - acc: 9.7943e-04 - val_loss: 5.2778e-05 - val_acc: 0.0000e+00
# Epoch 3/25
# 1021/1021 [==============================] - 1s 813us/step - loss: 0.0031 - acc: 9.7943e-04 - val_loss: 6.3515e-04 - val_acc: 0.0000e+00
# Epoch 4/25
# 1021/1021 [==============================] - 1s 866us/step - loss: 0.0034 - acc: 9.7943e-04 - val_loss: 0.0013 - val_acc: 0.0000e+00
# Epoch 5/25
# 1021/1021 [==============================] - 1s 745us/step - loss: 0.0043 - acc: 9.7943e-04 - val_loss: 0.0013 - val_acc: 0.0000e+00
# Epoch 6/25
# 1021/1021 [==============================] - 1s 726us/step - loss: 0.0038 - acc: 9.7943e-04 - val_loss: 9.0925e-04 - val_acc: 0.0000e+00
# Epoch 7/25
# 1021/1021 [==============================] - 1s 795us/step - loss: 0.0036 - acc: 9.7943e-04 - val_loss: 3.5191e-04 - val_acc: 0.0000e+00
# Epoch 8/25
# 1021/1021 [==============================] - 1s 883us/step - loss: 0.0030 - acc: 9.7943e-04 - val_loss: 4.5982e-05 - val_acc: 0.0000e+00
# Epoch 9/25
# 1021/1021 [==============================] - 1s 957us/step - loss: 0.0027 - acc: 9.7943e-04 - val_loss: 6.4083e-05 - val_acc: 0.0000e+00
# Epoch 10/25
# 1021/1021 [==============================] - 1s 790us/step - loss: 0.0029 - acc: 9.7943e-04 - val_loss: 2.1443e-04 - val_acc: 0.0000e+00
# Epoch 11/25
# 1021/1021 [==============================] - 1s 875us/step - loss: 0.0031 - acc: 9.7943e-04 - val_loss: 2.6205e-04 - val_acc: 0.0000e+00
# Epoch 12/25
# 1021/1021 [==============================] - 1s 780us/step - loss: 0.0028 - acc: 9.7943e-04 - val_loss: 1.8203e-04 - val_acc: 0.0000e+00
# Epoch 13/25
# 1021/1021 [==============================] - 1s 746us/step - loss: 0.0031 - acc: 9.7943e-04 - val_loss: 6.9434e-05 - val_acc: 0.0000e+00
# Epoch 14/25
# 1021/1021 [==============================] - 1s 800us/step - loss: 0.0029 - acc: 9.7943e-04 - val_loss: 1.9159e-05 - val_acc: 0.0000e+00
# Epoch 15/25
# 1021/1021 [==============================] - 1s 771us/step - loss: 0.0027 - acc: 9.7943e-04 - val_loss: 4.9954e-05 - val_acc: 0.0000e+00
# Epoch 16/25
# 1021/1021 [==============================] - 1s 792us/step - loss: 0.0028 - acc: 9.7943e-04 - val_loss: 1.0130e-04 - val_acc: 0.0000e+00
# Epoch 17/25
# 1021/1021 [==============================] - 1s 749us/step - loss: 0.0029 - acc: 9.7943e-04 - val_loss: 1.2213e-04 - val_acc: 0.0000e+00
# Epoch 18/25
# 1021/1021 [==============================] - 1s 736us/step - loss: 0.0026 - acc: 9.7943e-04 - val_loss: 9.6353e-05 - val_acc: 0.0000e+00
# Epoch 19/25
# 1021/1021 [==============================] - 1s 704us/step - loss: 0.0027 - acc: 9.7943e-04 - val_loss: 5.3961e-05 - val_acc: 0.0000e+00
# Epoch 20/25
# 1021/1021 [==============================] - 1s 828us/step - loss: 0.0028 - acc: 9.7943e-04 - val_loss: 2.7412e-05 - val_acc: 0.0000e+00
# Epoch 21/25
# 1021/1021 [==============================] - 1s 760us/step - loss: 0.0027 - acc: 9.7943e-04 - val_loss: 1.9163e-05 - val_acc: 0.0000e+00
# Epoch 22/25
# 1021/1021 [==============================] - 1s 728us/step - loss: 0.0027 - acc: 9.7943e-04 - val_loss: 2.2625e-05 - val_acc: 0.0000e+00
# Epoch 23/25
# 1021/1021 [==============================] - 1s 721us/step - loss: 0.0027 - acc: 9.7943e-04 - val_loss: 2.3548e-05 - val_acc: 0.0000e+00
# Epoch 24/25
# 1021/1021 [==============================] - 1s 794us/step - loss: 0.0025 - acc: 9.7943e-04 - val_loss: 2.1417e-05 - val_acc: 0.0000e+00
# Epoch 25/25
# 1021/1021 [==============================] - 1s 752us/step - loss: 0.0029 - acc: 9.7943e-04 - val_loss: 1.9176e-05 - val_acc: 0.0000e+00
# Train on 1021 samples, validate on 114 samples
# Epoch 1/25
# 1021/1021 [==============================] - 1s 803us/step - loss: 0.0027 - acc: 9.7943e-04 - val_loss: 2.3889e-05 - val_acc: 0.0000e+00
# Epoch 2/25
# 1021/1021 [==============================] - 1s 817us/step - loss: 0.0027 - acc: 9.7943e-04 - val_loss: 2.9491e-05 - val_acc: 0.0000e+00
# Epoch 3/25
# 1021/1021 [==============================] - 1s 751us/step - loss: 0.0027 - acc: 9.7943e-04 - val_loss: 2.7228e-05 - val_acc: 0.0000e+00
# Epoch 4/25
# 1021/1021 [==============================] - 1s 702us/step - loss: 0.0027 - acc: 9.7943e-04 - val_loss: 2.5336e-05 - val_acc: 0.0000e+00
# Epoch 5/25
# 1021/1021 [==============================] - 1s 693us/step - loss: 0.0028 - acc: 9.7943e-04 - val_loss: 2.3384e-05 - val_acc: 0.0000e+00
# Epoch 6/25
# 1021/1021 [==============================] - 1s 699us/step - loss: 0.0026 - acc: 9.7943e-04 - val_loss: 2.0650e-05 - val_acc: 0.0000e+00
# Epoch 7/25
# 1021/1021 [==============================] - 1s 830us/step - loss: 0.0026 - acc: 9.7943e-04 - val_loss: 1.9391e-05 - val_acc: 0.0000e+00
# Epoch 8/25
# 1021/1021 [==============================] - 1s 712us/step - loss: 0.0026 - acc: 9.7943e-04 - val_loss: 1.9650e-05 - val_acc: 0.0000e+00
# Epoch 9/25
# 1021/1021 [==============================] - 1s 719us/step - loss: 0.0027 - acc: 9.7943e-04 - val_loss: 2.2322e-05 - val_acc: 0.0000e+00
# Epoch 10/25
# 1021/1021 [==============================] - 1s 763us/step - loss: 0.0027 - acc: 9.7943e-04 - val_loss: 2.9939e-05 - val_acc: 0.0000e+00
# Epoch 11/25
# 1021/1021 [==============================] - 1s 692us/step - loss: 0.0028 - acc: 9.7943e-04 - val_loss: 3.8384e-05 - val_acc: 0.0000e+00
# Epoch 12/25
# 1021/1021 [==============================] - 1s 702us/step - loss: 0.0027 - acc: 9.7943e-04 - val_loss: 4.3984e-05 - val_acc: 0.0000e+00
# Epoch 13/25
# 1021/1021 [==============================] - 1s 764us/step - loss: 0.0029 - acc: 9.7943e-04 - val_loss: 3.5346e-05 - val_acc: 0.0000e+00
# Epoch 14/25
# 1021/1021 [==============================] - 1s 754us/step - loss: 0.0027 - acc: 9.7943e-04 - val_loss: 2.5070e-05 - val_acc: 0.0000e+00
# Epoch 15/25
# 1021/1021 [==============================] - 1s 739us/step - loss: 0.0027 - acc: 9.7943e-04 - val_loss: 2.0125e-05 - val_acc: 0.0000e+00
# Epoch 16/25
# 1021/1021 [==============================] - 1s 747us/step - loss: 0.0026 - acc: 9.7943e-04 - val_loss: 1.9388e-05 - val_acc: 0.0000e+00
# Epoch 17/25
# 1021/1021 [==============================] - 1s 698us/step - loss: 0.0029 - acc: 9.7943e-04 - val_loss: 2.0077e-05 - val_acc: 0.0000e+00
# Epoch 18/25
# 1021/1021 [==============================] - 1s 705us/step - loss: 0.0027 - acc: 9.7943e-04 - val_loss: 2.0185e-05 - val_acc: 0.0000e+00
# Epoch 19/25
# 1021/1021 [==============================] - 1s 773us/step - loss: 0.0027 - acc: 9.7943e-04 - val_loss: 2.2310e-05 - val_acc: 0.0000e+00
# Epoch 20/25
# 1021/1021 [==============================] - 1s 795us/step - loss: 0.0026 - acc: 9.7943e-04 - val_loss: 2.2802e-05 - val_acc: 0.0000e+00
# Epoch 21/25
# 1021/1021 [==============================] - 1s 801us/step - loss: 0.0025 - acc: 9.7943e-04 - val_loss: 2.3234e-05 - val_acc: 0.0000e+00
# Epoch 22/25
# 1021/1021 [==============================] - 1s 699us/step - loss: 0.0028 - acc: 9.7943e-04 - val_loss: 2.4323e-05 - val_acc: 0.0000e+00
# Epoch 23/25
# 1021/1021 [==============================] - 1s 690us/step - loss: 0.0026 - acc: 9.7943e-04 - val_loss: 2.8096e-05 - val_acc: 0.0000e+00
# Epoch 24/25
# 1021/1021 [==============================] - 1s 713us/step - loss: 0.0028 - acc: 9.7943e-04 - val_loss: 2.8891e-05 - val_acc: 0.0000e+00
# Epoch 25/25
# 1021/1021 [==============================] - 1s 719us/step - loss: 0.0027 - acc: 9.7943e-04 - val_loss: 3.3720e-05 - val_acc: 0.0000e+00
# Train on 1021 samples, validate on 114 samples
# Epoch 1/25
# 1021/1021 [==============================] - 1s 717us/step - loss: 0.0026 - acc: 9.7943e-04 - val_loss: 3.5140e-05 - val_acc: 0.0000e+00
# Epoch 2/25
# 1021/1021 [==============================] - 1s 729us/step - loss: 0.0026 - acc: 9.7943e-04 - val_loss: 3.3038e-05 - val_acc: 0.0000e+00
# Epoch 3/25
# 1021/1021 [==============================] - 1s 715us/step - loss: 0.0027 - acc: 9.7943e-04 - val_loss: 3.2901e-05 - val_acc: 0.0000e+00
# Epoch 4/25
# 1021/1021 [==============================] - 1s 724us/step - loss: 0.0029 - acc: 9.7943e-04 - val_loss: 2.9530e-05 - val_acc: 0.0000e+00
# Epoch 5/25
# 1021/1021 [==============================] - 1s 890us/step - loss: 0.0029 - acc: 9.7943e-04 - val_loss: 2.1875e-05 - val_acc: 0.0000e+00
# Epoch 6/25
# 1021/1021 [==============================] - 1s 731us/step - loss: 0.0027 - acc: 9.7943e-04 - val_loss: 2.0817e-05 - val_acc: 0.0000e+00
# Epoch 7/25
# 1021/1021 [==============================] - 1s 748us/step - loss: 0.0027 - acc: 9.7943e-04 - val_loss: 2.1420e-05 - val_acc: 0.0000e+00
# Epoch 8/25
# 1021/1021 [==============================] - 1s 748us/step - loss: 0.0026 - acc: 9.7943e-04 - val_loss: 2.1713e-05 - val_acc: 0.0000e+00
# Epoch 9/25
# 1021/1021 [==============================] - 1s 806us/step - loss: 0.0026 - acc: 9.7943e-04 - val_loss: 2.2204e-05 - val_acc: 0.0000e+00
# Epoch 10/25
# 1021/1021 [==============================] - 1s 805us/step - loss: 0.0027 - acc: 9.7943e-04 - val_loss: 2.0824e-05 - val_acc: 0.0000e+00
# Epoch 11/25
# 1021/1021 [==============================] - 1s 753us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 2.0072e-05 - val_acc: 0.0000e+00
# Epoch 12/25
# 1021/1021 [==============================] - 1s 817us/step - loss: 0.0027 - acc: 9.7943e-04 - val_loss: 2.1631e-05 - val_acc: 0.0000e+00
# Epoch 13/25
# 1021/1021 [==============================] - 1s 1ms/step - loss: 0.0026 - acc: 9.7943e-04 - val_loss: 2.0955e-05 - val_acc: 0.0000e+00
# Epoch 14/25
# 1021/1021 [==============================] - 1s 881us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 1.9741e-05 - val_acc: 0.0000e+00
# Epoch 15/25
# 1021/1021 [==============================] - 1s 782us/step - loss: 0.0026 - acc: 9.7943e-04 - val_loss: 1.9238e-05 - val_acc: 0.0000e+00
# Epoch 16/25
# 1021/1021 [==============================] - 1s 896us/step - loss: 0.0025 - acc: 9.7943e-04 - val_loss: 1.9279e-05 - val_acc: 0.0000e+00
# Epoch 17/25
# 1021/1021 [==============================] - 1s 854us/step - loss: 0.0025 - acc: 9.7943e-04 - val_loss: 2.0646e-05 - val_acc: 0.0000e+00
# Epoch 18/25
# 1021/1021 [==============================] - 1s 863us/step - loss: 0.0025 - acc: 9.7943e-04 - val_loss: 1.9254e-05 - val_acc: 0.0000e+00
# Epoch 19/25
# 1021/1021 [==============================] - 1s 867us/step - loss: 0.0026 - acc: 9.7943e-04 - val_loss: 1.9913e-05 - val_acc: 0.0000e+00
# Epoch 20/25
# 1021/1021 [==============================] - 1s 889us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 2.5806e-05 - val_acc: 0.0000e+00
# Epoch 21/25
# 1021/1021 [==============================] - 1s 774us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 3.2163e-05 - val_acc: 0.0000e+00
# Epoch 22/25
# 1021/1021 [==============================] - 1s 820us/step - loss: 0.0027 - acc: 9.7943e-04 - val_loss: 2.7637e-05 - val_acc: 0.0000e+00
# Epoch 23/25
# 1021/1021 [==============================] - 1s 771us/step - loss: 0.0026 - acc: 9.7943e-04 - val_loss: 2.0880e-05 - val_acc: 0.0000e+00
# Epoch 24/25
# 1021/1021 [==============================] - 1s 765us/step - loss: 0.0025 - acc: 9.7943e-04 - val_loss: 1.9978e-05 - val_acc: 0.0000e+00
# Epoch 25/25
# 1021/1021 [==============================] - 1s 728us/step - loss: 0.0025 - acc: 9.7943e-04 - val_loss: 2.6659e-05 - val_acc: 0.0000e+00
# Train on 1021 samples, validate on 114 samples
# Epoch 1/25
# 1021/1021 [==============================] - 1s 762us/step - loss: 0.0026 - acc: 9.7943e-04 - val_loss: 2.1192e-05 - val_acc: 0.0000e+00
# Epoch 2/25
# 1021/1021 [==============================] - 1s 798us/step - loss: 0.0026 - acc: 9.7943e-04 - val_loss: 2.0130e-05 - val_acc: 0.0000e+00
# Epoch 3/25
# 1021/1021 [==============================] - 1s 733us/step - loss: 0.0026 - acc: 9.7943e-04 - val_loss: 2.4175e-05 - val_acc: 0.0000e+00
# Epoch 4/25
# 1021/1021 [==============================] - 1s 724us/step - loss: 0.0028 - acc: 9.7943e-04 - val_loss: 3.0759e-05 - val_acc: 0.0000e+00
# Epoch 5/25
# 1021/1021 [==============================] - 1s 815us/step - loss: 0.0025 - acc: 9.7943e-04 - val_loss: 2.8766e-05 - val_acc: 0.0000e+00
# Epoch 6/25
# 1021/1021 [==============================] - 1s 808us/step - loss: 0.0025 - acc: 9.7943e-04 - val_loss: 2.2197e-05 - val_acc: 0.0000e+00
# Epoch 7/25
# 1021/1021 [==============================] - 1s 826us/step - loss: 0.0025 - acc: 9.7943e-04 - val_loss: 2.1590e-05 - val_acc: 0.0000e+00
# Epoch 8/25
# 1021/1021 [==============================] - 1s 791us/step - loss: 0.0027 - acc: 9.7943e-04 - val_loss: 2.1073e-05 - val_acc: 0.0000e+00
# Epoch 9/25
# 1021/1021 [==============================] - 1s 764us/step - loss: 0.0025 - acc: 9.7943e-04 - val_loss: 2.0160e-05 - val_acc: 0.0000e+00
# Epoch 10/25
# 1021/1021 [==============================] - 1s 728us/step - loss: 0.0025 - acc: 9.7943e-04 - val_loss: 1.9997e-05 - val_acc: 0.0000e+00
# Epoch 11/25
# 1021/1021 [==============================] - 1s 743us/step - loss: 0.0027 - acc: 9.7943e-04 - val_loss: 2.0786e-05 - val_acc: 0.0000e+00
# Epoch 12/25
# 1021/1021 [==============================] - 1s 780us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 2.4147e-05 - val_acc: 0.0000e+00
# Epoch 13/25
# 1021/1021 [==============================] - 1s 791us/step - loss: 0.0025 - acc: 9.7943e-04 - val_loss: 3.4300e-05 - val_acc: 0.0000e+00
# Epoch 14/25
# 1021/1021 [==============================] - 1s 869us/step - loss: 0.0026 - acc: 9.7943e-04 - val_loss: 3.4578e-05 - val_acc: 0.0000e+00
# Epoch 15/25
# 1021/1021 [==============================] - 1s 767us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 2.8684e-05 - val_acc: 0.0000e+00
# Epoch 16/25
# 1021/1021 [==============================] - 1s 786us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 2.4664e-05 - val_acc: 0.0000e+00
# Epoch 17/25
# 1021/1021 [==============================] - 1s 760us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 2.0824e-05 - val_acc: 0.0000e+00
# Epoch 18/25
# 1021/1021 [==============================] - 1s 837us/step - loss: 0.0025 - acc: 9.7943e-04 - val_loss: 1.9684e-05 - val_acc: 0.0000e+00
# Epoch 19/25
# 1021/1021 [==============================] - 1s 939us/step - loss: 0.0025 - acc: 9.7943e-04 - val_loss: 1.9350e-05 - val_acc: 0.0000e+00
# Epoch 20/25
# 1021/1021 [==============================] - 1s 825us/step - loss: 0.0028 - acc: 9.7943e-04 - val_loss: 2.0847e-05 - val_acc: 0.0000e+00
# Epoch 21/25
# 1021/1021 [==============================] - 1s 851us/step - loss: 0.0025 - acc: 9.7943e-04 - val_loss: 2.7081e-05 - val_acc: 0.0000e+00
# Epoch 22/25
# 1021/1021 [==============================] - 1s 851us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 2.8267e-05 - val_acc: 0.0000e+00
# Epoch 23/25
# 1021/1021 [==============================] - 1s 824us/step - loss: 0.0025 - acc: 9.7943e-04 - val_loss: 3.2834e-05 - val_acc: 0.0000e+00
# Epoch 24/25
# 1021/1021 [==============================] - 1s 734us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 3.7020e-05 - val_acc: 0.0000e+00
# Epoch 25/25
# 1021/1021 [==============================] - 1s 746us/step - loss: 0.0027 - acc: 9.7943e-04 - val_loss: 3.4766e-05 - val_acc: 0.0000e+00
# Train on 1021 samples, validate on 114 samples
# Epoch 1/25
# 1021/1021 [==============================] - 1s 745us/step - loss: 0.0025 - acc: 9.7943e-04 - val_loss: 2.5578e-05 - val_acc: 0.0000e+00
# Epoch 2/25
# 1021/1021 [==============================] - 1s 738us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 1.9236e-05 - val_acc: 0.0000e+00
# Epoch 3/25
# 1021/1021 [==============================] - 1s 707us/step - loss: 0.0025 - acc: 9.7943e-04 - val_loss: 2.5927e-05 - val_acc: 0.0000e+00
# Epoch 4/25
# 1021/1021 [==============================] - 1s 720us/step - loss: 0.0026 - acc: 9.7943e-04 - val_loss: 2.6420e-05 - val_acc: 0.0000e+00
# Epoch 5/25
# 1021/1021 [==============================] - 1s 747us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 2.0720e-05 - val_acc: 0.0000e+00
# Epoch 6/25
# 1021/1021 [==============================] - 1s 764us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 4.1359e-05 - val_acc: 0.0000e+00
# Epoch 7/25
# 1021/1021 [==============================] - 1s 723us/step - loss: 0.0025 - acc: 9.7943e-04 - val_loss: 6.8922e-05 - val_acc: 0.0000e+00
# Epoch 8/25
# 1021/1021 [==============================] - 1s 767us/step - loss: 0.0023 - acc: 9.7943e-04 - val_loss: 6.2440e-05 - val_acc: 0.0000e+00
# Epoch 9/25
# 1021/1021 [==============================] - 1s 755us/step - loss: 0.0025 - acc: 9.7943e-04 - val_loss: 3.5774e-05 - val_acc: 0.0000e+00
# Epoch 10/25
# 1021/1021 [==============================] - 1s 716us/step - loss: 0.0025 - acc: 9.7943e-04 - val_loss: 2.1186e-05 - val_acc: 0.0000e+00
# Epoch 11/25
# 1021/1021 [==============================] - 1s 738us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 1.9487e-05 - val_acc: 0.0000e+00
# Epoch 12/25
# 1021/1021 [==============================] - 1s 732us/step - loss: 0.0025 - acc: 9.7943e-04 - val_loss: 1.9171e-05 - val_acc: 0.0000e+00
# Epoch 13/25
# 1021/1021 [==============================] - 1s 739us/step - loss: 0.0026 - acc: 9.7943e-04 - val_loss: 1.9995e-05 - val_acc: 0.0000e+00
# Epoch 14/25
# 1021/1021 [==============================] - 1s 757us/step - loss: 0.0023 - acc: 9.7943e-04 - val_loss: 2.6357e-05 - val_acc: 0.0000e+00
# Epoch 15/25
# 1021/1021 [==============================] - 1s 695us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 2.9138e-05 - val_acc: 0.0000e+00
# Epoch 16/25
# 1021/1021 [==============================] - 1s 707us/step - loss: 0.0023 - acc: 9.7943e-04 - val_loss: 2.7195e-05 - val_acc: 0.0000e+00
# Epoch 17/25
# 1021/1021 [==============================] - 1s 713us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 2.1013e-05 - val_acc: 0.0000e+00
# Epoch 18/25
# 1021/1021 [==============================] - 1s 741us/step - loss: 0.0023 - acc: 9.7943e-04 - val_loss: 2.1899e-05 - val_acc: 0.0000e+00
# Epoch 19/25
# 1021/1021 [==============================] - 1s 717us/step - loss: 0.0026 - acc: 9.7943e-04 - val_loss: 2.3380e-05 - val_acc: 0.0000e+00
# Epoch 20/25
# 1021/1021 [==============================] - 1s 709us/step - loss: 0.0021 - acc: 9.7943e-04 - val_loss: 2.4224e-05 - val_acc: 0.0000e+00
# Epoch 21/25
# 1021/1021 [==============================] - 1s 729us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 2.4112e-05 - val_acc: 0.0000e+00
# Epoch 22/25
# 1021/1021 [==============================] - 1s 816us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 2.6429e-05 - val_acc: 0.0000e+00
# Epoch 23/25
# 1021/1021 [==============================] - 1s 887us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 3.2371e-05 - val_acc: 0.0000e+00
# Epoch 24/25
# 1021/1021 [==============================] - 1s 712us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 3.4358e-05 - val_acc: 0.0000e+00
# Epoch 25/25
# 1021/1021 [==============================] - 1s 707us/step - loss: 0.0025 - acc: 9.7943e-04 - val_loss: 2.7739e-05 - val_acc: 0.0000e+00
# Train on 1021 samples, validate on 114 samples
# Epoch 1/25
# 1021/1021 [==============================] - 1s 706us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 2.4994e-05 - val_acc: 0.0000e+00
# Epoch 2/25
# 1021/1021 [==============================] - 1s 736us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 2.4936e-05 - val_acc: 0.0000e+00
# Epoch 3/25
# 1021/1021 [==============================] - 1s 737us/step - loss: 0.0023 - acc: 9.7943e-04 - val_loss: 2.4627e-05 - val_acc: 0.0000e+00
# Epoch 4/25
# 1021/1021 [==============================] - 1s 753us/step - loss: 0.0025 - acc: 9.7943e-04 - val_loss: 2.2860e-05 - val_acc: 0.0000e+00
# Epoch 5/25
# 1021/1021 [==============================] - 1s 750us/step - loss: 0.0023 - acc: 9.7943e-04 - val_loss: 2.6473e-05 - val_acc: 0.0000e+00
# Epoch 6/25
# 1021/1021 [==============================] - 1s 752us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 2.4281e-05 - val_acc: 0.0000e+00
# Epoch 7/25
# 1021/1021 [==============================] - 1s 772us/step - loss: 0.0025 - acc: 9.7943e-04 - val_loss: 2.1201e-05 - val_acc: 0.0000e+00
# Epoch 8/25
# 1021/1021 [==============================] - 1s 765us/step - loss: 0.0023 - acc: 9.7943e-04 - val_loss: 1.9190e-05 - val_acc: 0.0000e+00
# Epoch 9/25
# 1021/1021 [==============================] - 1s 762us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 2.0510e-05 - val_acc: 0.0000e+00
# Epoch 10/25
# 1021/1021 [==============================] - 1s 753us/step - loss: 0.0025 - acc: 9.7943e-04 - val_loss: 1.9125e-05 - val_acc: 0.0000e+00
# Epoch 11/25
# 1021/1021 [==============================] - 1s 755us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 2.4996e-05 - val_acc: 0.0000e+00
# Epoch 12/25
# 1021/1021 [==============================] - 1s 753us/step - loss: 0.0025 - acc: 9.7943e-04 - val_loss: 3.3596e-05 - val_acc: 0.0000e+00
# Epoch 13/25
# 1021/1021 [==============================] - 1s 742us/step - loss: 0.0025 - acc: 9.7943e-04 - val_loss: 2.5902e-05 - val_acc: 0.0000e+00
# Epoch 14/25
# 1021/1021 [==============================] - 1s 716us/step - loss: 0.0023 - acc: 9.7943e-04 - val_loss: 1.9182e-05 - val_acc: 0.0000e+00
# Epoch 15/25
# 1021/1021 [==============================] - 1s 690us/step - loss: 0.0023 - acc: 9.7943e-04 - val_loss: 1.9289e-05 - val_acc: 0.0000e+00
# Epoch 16/25
# 1021/1021 [==============================] - 1s 723us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 1.9523e-05 - val_acc: 0.0000e+00
# Epoch 17/25
# 1021/1021 [==============================] - 1s 779us/step - loss: 0.0022 - acc: 9.7943e-04 - val_loss: 2.0210e-05 - val_acc: 0.0000e+00
# Epoch 18/25
# 1021/1021 [==============================] - 1s 726us/step - loss: 0.0023 - acc: 9.7943e-04 - val_loss: 3.2024e-05 - val_acc: 0.0000e+00
# Epoch 19/25
# 1021/1021 [==============================] - 1s 719us/step - loss: 0.0023 - acc: 9.7943e-04 - val_loss: 3.3891e-05 - val_acc: 0.0000e+00
# Epoch 20/25
# 1021/1021 [==============================] - 1s 704us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 2.7472e-05 - val_acc: 0.0000e+00
# Epoch 21/25
# 1021/1021 [==============================] - 1s 701us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 2.3452e-05 - val_acc: 0.0000e+00
# Epoch 22/25
# 1021/1021 [==============================] - 1s 706us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 1.9925e-05 - val_acc: 0.0000e+00
# Epoch 23/25
# 1021/1021 [==============================] - 1s 701us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 2.0748e-05 - val_acc: 0.0000e+00
# Epoch 24/25
# 1021/1021 [==============================] - 1s 704us/step - loss: 0.0023 - acc: 9.7943e-04 - val_loss: 2.6018e-05 - val_acc: 0.0000e+00
# Epoch 25/25
# 1021/1021 [==============================] - 1s 706us/step - loss: 0.0023 - acc: 9.7943e-04 - val_loss: 2.6334e-05 - val_acc: 0.0000e+00
# Train on 1021 samples, validate on 114 samples
# Epoch 1/25
# 1021/1021 [==============================] - 1s 954us/step - loss: 0.0022 - acc: 9.7943e-04 - val_loss: 2.4175e-05 - val_acc: 0.0000e+00
# Epoch 2/25
# 1021/1021 [==============================] - 1s 821us/step - loss: 0.0023 - acc: 9.7943e-04 - val_loss: 2.1637e-05 - val_acc: 0.0000e+00
# Epoch 3/25
# 1021/1021 [==============================] - 1s 975us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 2.1125e-05 - val_acc: 0.0000e+00
# Epoch 4/25
# 1021/1021 [==============================] - 1s 860us/step - loss: 0.0023 - acc: 9.7943e-04 - val_loss: 2.2448e-05 - val_acc: 0.0000e+00
# Epoch 5/25
# 1021/1021 [==============================] - 1s 876us/step - loss: 0.0023 - acc: 9.7943e-04 - val_loss: 2.4598e-05 - val_acc: 0.0000e+00
# Epoch 6/25
# 1021/1021 [==============================] - 1s 834us/step - loss: 0.0023 - acc: 9.7943e-04 - val_loss: 2.4576e-05 - val_acc: 0.0000e+00
# Epoch 7/25
# 1021/1021 [==============================] - 1s 764us/step - loss: 0.0023 - acc: 9.7943e-04 - val_loss: 2.0147e-05 - val_acc: 0.0000e+00
# Epoch 8/25
# 1021/1021 [==============================] - 1s 742us/step - loss: 0.0022 - acc: 9.7943e-04 - val_loss: 1.9974e-05 - val_acc: 0.0000e+00
# Epoch 9/25
# 1021/1021 [==============================] - 1s 724us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 2.6812e-05 - val_acc: 0.0000e+00
# Epoch 10/25
# 1021/1021 [==============================] - 1s 775us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 3.9070e-05 - val_acc: 0.0000e+00
# Epoch 11/25
# 1021/1021 [==============================] - 1s 817us/step - loss: 0.0023 - acc: 9.7943e-04 - val_loss: 3.6838e-05 - val_acc: 0.0000e+00
# Epoch 12/25
# 1021/1021 [==============================] - 1s 863us/step - loss: 0.0022 - acc: 9.7943e-04 - val_loss: 2.1306e-05 - val_acc: 0.0000e+00
# Epoch 13/25
# 1021/1021 [==============================] - 1s 804us/step - loss: 0.0023 - acc: 9.7943e-04 - val_loss: 2.2198e-05 - val_acc: 0.0000e+00
# Epoch 14/25
# 1021/1021 [==============================] - 1s 848us/step - loss: 0.0022 - acc: 9.7943e-04 - val_loss: 2.6460e-05 - val_acc: 0.0000e+00
# Epoch 15/25
# 1021/1021 [==============================] - 1s 831us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 1.9185e-05 - val_acc: 0.0000e+00
# Epoch 16/25
# 1021/1021 [==============================] - 1s 844us/step - loss: 0.0022 - acc: 9.7943e-04 - val_loss: 3.2936e-05 - val_acc: 0.0000e+00
# Epoch 17/25
# 1021/1021 [==============================] - 1s 733us/step - loss: 0.0023 - acc: 9.7943e-04 - val_loss: 6.3381e-05 - val_acc: 0.0000e+00
# Epoch 18/25
# 1021/1021 [==============================] - 1s 737us/step - loss: 0.0025 - acc: 9.7943e-04 - val_loss: 4.0627e-05 - val_acc: 0.0000e+00
# Epoch 19/25
# 1021/1021 [==============================] - 1s 707us/step - loss: 0.0023 - acc: 9.7943e-04 - val_loss: 1.9891e-05 - val_acc: 0.0000e+00
# Epoch 20/25
# 1021/1021 [==============================] - 1s 712us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 3.1536e-05 - val_acc: 0.0000e+00
# Epoch 21/25
# 1021/1021 [==============================] - 1s 711us/step - loss: 0.0024 - acc: 9.7943e-04 - val_loss: 2.2038e-05 - val_acc: 0.0000e+00
# Epoch 22/25
# 1021/1021 [==============================] - 1s 708us/step - loss: 0.0022 - acc: 9.7943e-04 - val_loss: 2.4798e-05 - val_acc: 0.0000e+00
# Epoch 23/25
# 1021/1021 [==============================] - 1s 766us/step - loss: 0.0022 - acc: 9.7943e-04 - val_loss: 6.2553e-05 - val_acc: 0.0000e+00
# Epoch 24/25
# 1021/1021 [==============================] - 1s 760us/step - loss: 0.0025 - acc: 9.7943e-04 - val_loss: 5.0100e-05 - val_acc: 0.0000e+00
# Epoch 25/25
# 1021/1021 [==============================] - 1s 749us/step - loss: 0.0022 - acc: 9.7943e-04 - val_loss: 2.1168e-05 - val_acc: 0.0000e+00

# %%
# print(df_to_predict['Close'].values)
